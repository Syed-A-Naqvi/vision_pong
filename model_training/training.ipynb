# %%
import torch
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\syeda\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# First, unset any CUDA variables
# os.environ.pop('CUDA_VISIBLE_DEVICES', None)
torch.cuda.empty_cache()

# Then wait a moment and reset
import time
time.sleep(3)

# Now set the device
# os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# Force PyTorch to reinitialize CUDA
torch.cuda.init()

# Verify status
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"CUDA device count: {torch.cuda.device_count()}")
print(f"Current CUDA device: {torch.cuda.current_device() if torch.cuda.is_available() else 'None'}")
print(f"CUDA_VISIBLE_DEVICES: {os.environ.get('CUDA_VISIBLE_DEVICES')}")
print(f"CUDA version: {torch.version.cuda}")
# Out:
# CUDA available: True
# CUDA device count: 1
# Current CUDA device: 0
# CUDA_VISIBLE_DEVICES: None
# CUDA version: 12.4

# %%
# # Load models
# model_8s_pretrained = YOLO('yolov8s.pt')
# model_11s_pretrained = YOLO('yolo11s.pt')
model_11n_pretrained = YOLO('yolo11n.pt')
# model_8s_finetuned = YOLO('./runs/detect/hand_detection_8s/weights/best.pt')
# model_11s_finetuned = YOLO('./runs/detect/hand_detection_11s/weights/best.pt')
model_11n_finetuned = YOLO('./runs/detect/hand_detection_11n/weights/last.pt')

# # Fine-tune the model on your dataset
# results_8s_finetuned = model_8s_finetuned.train(
#     data='./datasets/data.yaml',
#     epochs=100,
#     imgsz=640,
#     batch=8,
#     resume=True,
#     name='hand_detection_8s',  # name of the run for saving results
#     patience=10
# )
# results_11s_finetuned = model_11s_finetuned.train(
#     data='./datasets/data.yaml',
#     epochs=100,
#     imgsz=640,
#     batch=8,
#     resume=True,
#     name='hand_detection_11s',  # name of the run for saving results
#     patience=10
# )
results_11n_finetuned = model_11n_finetuned.train(
    data='./datasets/data.yaml',
    epochs=100,
    imgsz=640,
    resume=True,
    batch=8,
    name='hand_detection_11n',  # name of the run for saving results
    patience=10
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.100 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.99 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce GTX 1060, 6057MiB)
# engine/trainer: task=detect, mode=train, model=runs/detect/hand_detection_11n/weights/last.pt, data=./datasets/data.yaml, epochs=100, time=None, patience=10, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=hand_detection_11n, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=runs/detect/hand_detection_11n/weights/last.pt, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/hand_detection_11n
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/labels.cache... 7898 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7898/7898 [00:00<?, ?it/s]
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/CARDS_LIVINGROOM_T_B_frame_1750.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_114.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_117.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_120.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_131.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_145.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_173.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_174.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_19.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_193.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_223.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_238.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_264.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_290.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_3.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_319.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_345.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_35.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_374.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_396.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_397.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_40.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_437.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_446.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_45.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_455.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_464.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_496.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_499.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_505.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_89.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_90.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Inria_92.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_10.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_101.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_144.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_153.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_169.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_172.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_180.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_192.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_237.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_238.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_247.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_250.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_268.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_281.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_282.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_290.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_291.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_297.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_298.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_300.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_308.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_312.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_315.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_326.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_353.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_359.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_372.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_378.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_389.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Poselet_56.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_231.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_239.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_25.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_281.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_284.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_57.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/Skin_80.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_1121.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_1260.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_304.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_412.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_686.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_723.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/train/images/VOC2010_749.jpg: 1 duplicate labels removed
# val: Scanning /home/syarnaq/Documents/Arham/School/UOIT/github/air_paddle/model_training/datasets/val/labels.cache... 1216 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1216/1216 [00:00<?, ?it/s]
# Plotting labels to runs/detect/hand_detection_11n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Resuming training runs/detect/hand_detection_11n/weights/last.pt from epoch 81 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/hand_detection_11n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      1.33G     0.9224      0.491      0.982          9        640: 100%|██████████| 988/988 [04:31<00:00,  3.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:11<00:00,  6.87it/s]
#                    all       1216       3396      0.916      0.852      0.932      0.633
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      1.34G     0.9156     0.4861     0.9822          9        640: 100%|██████████| 988/988 [04:34<00:00,  3.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:10<00:00,  7.14it/s]
#                    all       1216       3396       0.92      0.849      0.932      0.632
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      1.35G     0.9188     0.4865     0.9818          5        640: 100%|██████████| 988/988 [04:33<00:00,  3.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:11<00:00,  6.81it/s]
#                    all       1216       3396      0.909      0.857      0.931      0.631
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      1.35G     0.9202     0.4886     0.9848          9        640: 100%|██████████| 988/988 [04:38<00:00,  3.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:11<00:00,  6.59it/s]
#                    all       1216       3396      0.914      0.852       0.93       0.63
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      1.35G     0.9372     0.4982     0.9896          6        640: 100%|██████████| 988/988 [04:35<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:11<00:00,  6.74it/s]
#                    all       1216       3396      0.911      0.854      0.931      0.628
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      1.36G     0.9347     0.4927     0.9886         13        640: 100%|██████████| 988/988 [04:24<00:00,  3.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:10<00:00,  7.20it/s]
#                    all       1216       3396      0.921      0.851      0.932      0.629
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      1.36G     0.9323     0.4927     0.9862         19        640: 100%|██████████| 988/988 [04:39<00:00,  3.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:11<00:00,  6.57it/s]
#                    all       1216       3396      0.921      0.855      0.934       0.63
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      1.36G      0.926     0.4884     0.9835         10        640: 100%|██████████| 988/988 [04:44<00:00,  3.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:11<00:00,  6.37it/s]
#                    all       1216       3396      0.922      0.851      0.933       0.63
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      1.36G     0.9264     0.4888     0.9874         11        640: 100%|██████████| 988/988 [04:58<00:00,  3.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:12<00:00,  5.90it/s]
#                    all       1216       3396      0.923      0.846      0.932       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      1.36G     0.9303     0.4889     0.9848          6        640: 100%|██████████| 988/988 [04:50<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:12<00:00,  6.24it/s]
#                    all       1216       3396      0.926      0.842      0.931      0.629
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      1.36G     0.9591     0.4731     0.9821          4        640: 100%|██████████| 988/988 [04:54<00:00,  3.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:12<00:00,  6.31it/s]
#                    all       1216       3396      0.923      0.843      0.931       0.63
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 81, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 11 epochs completed in 0.894 hours.
# Optimizer stripped from runs/detect/hand_detection_11n/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/hand_detection_11n/weights/best.pt, 5.5MB
#
# Validating runs/detect/hand_detection_11n/weights/best.pt...
# Ultralytics 8.3.99 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce GTX 1060, 6057MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 76/76 [00:12<00:00,  5.85it/s]
#                    all       1216       3396      0.909      0.862      0.936      0.633
# Speed: 0.3ms preprocess, 6.7ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/hand_detection_11n
